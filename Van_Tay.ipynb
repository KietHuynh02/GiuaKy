# %% [markdown]
# <a href="https://colab.research.google.com/github/KietHuynh02/GiuaKy/blob/main/Van_Tay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from numpy import asarray, save
from keras.utils import load_img, img_to_array

folder = 'drive/MyDrive/VanTay/'

photos, labels = list(), list()
for file in listdir(folder):
  output = 0.0
  if file.startswith('Nangdong '):
    output = 1.0
  if file.startswith('Quyetdoan '):
    output = 2.0
  if file.startswith('Suckhoetot '):
    output = 3.0
  if file.startswith('Thongminh '):
    output = 4.0

  photo = load_img(folder + file, target_size =(128,128))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
# Train
photos_train = asarray(photos)
labels_train = asarray(labels)
print(photos_train.shape,labels_train.shape)
# Out:
# (308, 128, 128, 3) (308,)

# %%
folder = 'drive/MyDrive/VanTay_Test/'

photos, labels = list(), list()
for file in listdir(folder):
  output = 0.0
  if file.startswith('Nangdong '):
    output = 1.0
  if file.startswith('Quyetdoan '):
    output = 2.0
  if file.startswith('Suckhoetot '):
    output = 3.0
  if file.startswith('Thongminh '):
    output = 4.0

  photo = load_img(folder + file, target_size =(128,128))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
# Test
photos_test = asarray(photos)
labels_test = asarray(labels)
print(photos_test.shape,labels_test.shape)
# Out:
# (12, 128, 128, 3) (12,)

# %%
class_VanTay = {1: 'Năng Động',2: 'Quyết Đoán',3: 'Sức Khỏe Tốt',
                4: 'Thông Minh'}

# %%
#Reshape the sets and rescale within the byte range
photos_train = photos_train.reshape(308,128,128,3)
photos_train = photos_train.astype('float32')/255
photos_test = photos_test.reshape(12, 128, 128, 3)
photos_test = photos_test.astype('float32')/255
# One-hot encode the target classes
from keras.utils import to_categorical 
labels_train = to_categorical(labels_train)
labels_test = to_categorical(labels_test)

# %%
(photos_train.shape, labels_train.shape),(photos_test.shape, labels_test.shape)
# Out:
# (((308, 128, 128, 3), (308, 5)), ((12, 128, 128, 3), (12, 5)))

# %%
from keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D,Normalization
from keras.models import Sequential,Model
from keras import Input
from keras.layers import LeakyReLU
from keras.optimizers import Adam

batch_size = 64
epochs = 50
classes = 5

model = Sequential()
# CNN
model.add(Conv2D(32,kernel_size=(3,3), kernel_initializer='he_uniform',activation='linear',input_shape=(128,128,3),padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding = 'same'))
#_________________________________________________________

model.add(Conv2D(64,(3,3), kernel_initializer='he_uniform',activation = 'relu',padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding='same'))
#__________________________________________________________

model.add(Conv2D(128,(3,3), kernel_initializer='he_uniform',activation = 'relu', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2),padding= 'same'))
#__________________________________________________________

model.add(Conv2D(256,(3,3), kernel_initializer='he_uniform',activation = 'relu', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2),padding= 'same'))
#__________________________________________________________

model.add(Conv2D(512,(3,3), kernel_initializer='he_uniform',activation = 'relu', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2),padding= 'same'))
# ANN
model.add(Flatten())
model.add(Dense(128,activation = 'relu'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(64,activation = 'relu'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(classes ,activation = 'softmax'))

# Compile
model.compile(optimizer = Adam(), loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.summary()

train = model.fit(photos_train, labels_train, batch_size = batch_size ,epochs = epochs, verbose = 1)
test_loss, test_acc = model.evaluate(photos_test, labels_test)
print('Do chinh xac cua ham', test_acc)
print('Ham mat mat', test_loss)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  leaky_re_lu (LeakyReLU)     (None, 128, 128, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 64, 64, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       295168
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 16, 16, 256)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 8, 8, 512)         0
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 128)               1048704
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 2,625,861
# Trainable params: 2,625,861
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 5/5 [==============================] - 12s 316ms/step - loss: 6.3618 - accuracy: 0.2890
# Epoch 2/50
# 5/5 [==============================] - 0s 48ms/step - loss: 1.4214 - accuracy: 0.2338
# Epoch 3/50
# 5/5 [==============================] - 0s 45ms/step - loss: 1.2860 - accuracy: 0.3734
# Epoch 4/50
# 5/5 [==============================] - 0s 44ms/step - loss: 1.1177 - accuracy: 0.5812
# Epoch 5/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.8993 - accuracy: 0.5617
# Epoch 6/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.5642 - accuracy: 0.8409
# Epoch 7/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.5642 - accuracy: 0.7890
# Epoch 8/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3862 - accuracy: 0.8571
# Epoch 9/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3009 - accuracy: 0.8994
# Epoch 10/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2229 - accuracy: 0.9318
# Epoch 11/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2348 - accuracy: 0.9253
# Epoch 12/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1535 - accuracy: 0.9448
# Epoch 13/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0929 - accuracy: 0.9805
# Epoch 14/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0627 - accuracy: 0.9805
# Epoch 15/50
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0622 - accuracy: 0.9773
# Epoch 16/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0538 - accuracy: 0.9870
# Epoch 17/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0358 - accuracy: 0.9903
# Epoch 18/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0346 - accuracy: 0.9870
# Epoch 19/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0328 - accuracy: 0.9903
# Epoch 20/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0223 - accuracy: 0.9968
# Epoch 21/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0302 - accuracy: 0.9903
# Epoch 22/50
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 23/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 24/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 25/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 26/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 27/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 28/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 29/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 30/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 31/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 32/50
# 5/5 [==============================] - 0s 44ms/step - loss: 9.3527e-04 - accuracy: 1.0000
# Epoch 33/50
# 5/5 [==============================] - 0s 46ms/step - loss: 9.4498e-04 - accuracy: 1.0000
# Epoch 34/50
# 5/5 [==============================] - 0s 44ms/step - loss: 8.4025e-04 - accuracy: 1.0000
# Epoch 35/50
# 5/5 [==============================] - 0s 43ms/step - loss: 8.7457e-04 - accuracy: 1.0000
# Epoch 36/50
# 5/5 [==============================] - 0s 45ms/step - loss: 6.4512e-04 - accuracy: 1.0000
# Epoch 37/50
# 5/5 [==============================] - 0s 44ms/step - loss: 6.2334e-04 - accuracy: 1.0000
# Epoch 38/50
# 5/5 [==============================] - 0s 44ms/step - loss: 5.8371e-04 - accuracy: 1.0000
# Epoch 39/50
# 5/5 [==============================] - 0s 44ms/step - loss: 5.0870e-04 - accuracy: 1.0000
# Epoch 40/50
# 5/5 [==============================] - 0s 44ms/step - loss: 5.1415e-04 - accuracy: 1.0000
# Epoch 41/50
# 5/5 [==============================] - 0s 44ms/step - loss: 4.5440e-04 - accuracy: 1.0000
# Epoch 42/50
# 5/5 [==============================] - 0s 45ms/step - loss: 4.4898e-04 - accuracy: 1.0000
# Epoch 43/50
# 5/5 [==============================] - 0s 44ms/step - loss: 4.5593e-04 - accuracy: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 0s 44ms/step - loss: 4.0896e-04 - accuracy: 1.0000
# Epoch 45/50
# 5/5 [==============================] - 0s 43ms/step - loss: 3.5653e-04 - accuracy: 1.0000
# Epoch 46/50
# 5/5 [==============================] - 0s 46ms/step - loss: 3.4350e-04 - accuracy: 1.0000
# Epoch 47/50
# 5/5 [==============================] - 0s 51ms/step - loss: 3.1905e-04 - accuracy: 1.0000
# Epoch 48/50
# 5/5 [==============================] - 0s 47ms/step - loss: 3.0409e-04 - accuracy: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 0s 48ms/step - loss: 2.8972e-04 - accuracy: 1.0000
# Epoch 50/50
# 5/5 [==============================] - 0s 46ms/step - loss: 2.7184e-04 - accuracy: 1.0000
# 1/1 [==============================] - 1s 530ms/step - loss: 0.6713 - accuracy: 0.9167
# Do chinh xac cua ham 0.9166666865348816
# Ham mat mat 0.6712513566017151

# %%
model.save('drive/MyDrive/modelVanTay.h5')

# %%
import matplotlib.pyplot as plt
accuracy = train.history['accuracy']
loss = train.history['loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'r-', label = 'Training accuracy')
plt.plot(epochs, loss, 'b', label = 'Training loss')
plt.legend(['Train accuracy', 'Train loss'])
plt.show()

# %%
#test
import numpy as np 
filePath = '/content/drive/MyDrive/Thongminh.jpg'
testImage = load_img(filePath, color_mode = 'rgb', target_size=(128,128))
arrayImage = img_to_array(testImage).reshape(1,128,128,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", class_VanTay[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 455ms/step
# Predicted:  Thông Minh

# %%
filePath = '/content/drive/MyDrive/Suckhoetot.jpg'
testImage = load_img(filePath, color_mode = 'rgb', target_size=(128,128))
arrayImage = img_to_array(testImage).reshape(1,128,128,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", class_VanTay[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Predicted:  Sức Khỏe Tốt

# %%
filePath = '/content/drive/MyDrive/Nangdong.jpg'
testImage = load_img(filePath, color_mode = 'rgb', target_size=(128,128))
arrayImage = img_to_array(testImage).reshape(1,128,128,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", class_VanTay[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Predicted:  Năng Động
