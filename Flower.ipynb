# %% [markdown]
# <a href="https://colab.research.google.com/github/KietHuynh02/GiuaKy/blob/main/Flower.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from numpy import asarray, save
from keras.utils import load_img, img_to_array

folder = 'drive/MyDrive/Flower/'

photos, labels = list(), list()
for file in listdir(folder):
  output = 0.0
  if file.startswith('Daisy '):
    output = 1.0
  if file.startswith('Iris '):
    output = 2.0
  if file.startswith('Rose '):
    output = 3.0
  if file.startswith('Tulip '):
    output = 4.0
  if file.startswith('Water_Lily '):
    output = 5.0

  photo = load_img(folder + file, target_size =(128,128))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
# Train
photos_train = asarray(photos)
labels_train = asarray(labels)
print(photos_train.shape,labels_train.shape)
# Out:
# (4621, 128, 128, 3) (4621,)

# %%
folder = 'drive/MyDrive/Flower_Test/'

photos, labels = list(), list()
for file in listdir(folder):
  output = 0.0
  if file.startswith('Daisy '):
    output = 1.0
  if file.startswith('Iris '):
    output = 2.0
  if file.startswith('Rose '):
    output = 3.0
  if file.startswith('Tulip '):
    output = 4.0
  if file.startswith('Water_Lily '):
    output = 5.0

  photo = load_img(folder + file, target_size =(128,128))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
# Test
photos_test = asarray(photos)
labels_test = asarray(labels)
print(photos_test.shape,labels_test.shape)
# Out:
# (482, 128, 128, 3) (482,)

# %%
class_Flower =    {1: 'Daisy',2: 'Iris',3: 'Rose',
                  4: 'Tulip',5: 'Water_Lily'}

# %%
#Reshape the sets and rescale within the byte range
photos_train = photos_train.reshape(4621,128,128,3)
photos_train = photos_train.astype('float32')/255
photos_test = photos_test.reshape(482, 128, 128, 3)
photos_test = photos_test.astype('float32')/255

# %%
# One-hot encode the target classes
from keras.utils import to_categorical 
labels_train = to_categorical(labels_train)
labels_test = to_categorical(labels_test)

# %%
(photos_train.shape, labels_train.shape),(photos_test.shape, labels_test.shape)
# Out:
# (((4621, 128, 128, 3), (4621, 6)), ((482, 128, 128, 3), (482, 6)))

# %%
from keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D,Normalization
from keras.models import Sequential,Model
from keras import Input
from keras.layers import LeakyReLU
from keras.optimizers import Adam

batch_size = 64
epochs = 50
classes = 6

model = Sequential()
# CNN
model.add(Conv2D(32,kernel_size=(3,3),activation='linear',input_shape=(128,128,3),padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding = 'same'))
#_________________________________________________________

model.add(Conv2D(64,(3,3),activation = 'relu',padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding='same'))
#__________________________________________________________

model.add(Conv2D(128,(3,3),activation = 'relu', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2),padding= 'same'))
#__________________________________________________________

model.add(Conv2D(256,(3,3),activation = 'relu', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2),padding= 'same'))
#__________________________________________________________

model.add(Conv2D(512,(3,3),activation = 'relu', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2),padding= 'same'))
# ANN
model.add(Flatten())
model.add(Dense(128,activation = 'relu'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(64,activation = 'relu'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(classes ,activation = 'softmax'))

# Compile
model.compile(optimizer = Adam(), loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.summary()

train = model.fit(photos_train, labels_train, batch_size = batch_size ,epochs = epochs, verbose = 1)
test_loss, test_acc = model.evaluate(photos_test, labels_test)
print('Do chinh xac cua ham', test_acc)
print('Ham mat mat', test_loss)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  leaky_re_lu (LeakyReLU)     (None, 128, 128, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 64, 64, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       295168
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 16, 16, 256)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 8, 8, 512)         0
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 128)               1048704
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 64)                0
#
#  dense_2 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 2,625,926
# Trainable params: 2,625,926
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 73/73 [==============================] - 14s 54ms/step - loss: 1.2449 - accuracy: 0.4850
# Epoch 2/50
# 73/73 [==============================] - 3s 44ms/step - loss: 0.8803 - accuracy: 0.6579
# Epoch 3/50
# 73/73 [==============================] - 3s 44ms/step - loss: 0.7785 - accuracy: 0.7053
# Epoch 4/50
# 73/73 [==============================] - 3s 45ms/step - loss: 0.6364 - accuracy: 0.7682
# Epoch 5/50
# 73/73 [==============================] - 4s 48ms/step - loss: 0.5031 - accuracy: 0.8213
# Epoch 6/50
# 73/73 [==============================] - 3s 45ms/step - loss: 0
# Epoch 35/50
# 73/73 [==============================] - 4s 55ms/step - loss: 2.3037e-05 - accuracy: 1.0000
# Epoch 36/50
# 73/73 [==============================] - 4s 53ms/step - loss: 2.1457e-05 - accuracy: 1.0000
# Epoch 37/50
# 73/73 [==============================] - 4s 51ms/step - loss: 1.9003e-05 - accuracy: 1.0000
# Epoch 38/50
# 73/73 [==============================] - 4s 50ms/step - loss: 1.7312e-05 - accuracy: 1.0000
# Epoch 39/50
# 73/73 [==============================] - 4s 51ms/step - loss: 1.6015e-05 - accuracy: 1.0000
# Epoch 40/50
# 73/73 [==============================] - 4s 49ms/step - loss: 1.4575e-05 - accuracy: 1.0000
# Epoch 41/50
# 73/73 [==============================] - 4s 59ms/step - loss: 1.3480e-05 - accuracy: 1.0000
# Epoch 42/50
# 73/73 [==============================] - 4s 49ms/step - loss: 1.2531e-05 - accuracy: 1.0000
# Epoch 43/50
# 73/73 [==============================] - 3s 45ms/step - loss: 1.1749e-05 - accuracy: 1.0000
# Epoch 44/50
# 73/73 [==============================] - 3s 47ms/step - loss: 1.0873e-05 - accuracy: 1.0000
# Epoch 45/50
# 73/73 [==============================] - 4s 48ms/step - loss: 1.0111e-05 - accuracy: 1.0000
# Epoch 46/50
# 73/73 [==============================] - 3s 46ms/step - loss: 9.4073e-06 - accuracy: 1.0000
# Epoch 47/50
# 73/73 [==============================] - 3s 46ms/step - loss: 8.8022e-06 - accuracy: 1.0000
# Epoch 48/50
# 73/73 [==============================] - 3s 47ms/step - loss: 8.2903e-06 - accuracy: 1.0000
# Epoch 49/50
# 73/73 [==============================] - 4s 49ms/step - loss: 7.6607e-06 - accuracy: 1.0000
# Epoch 50/50
# 73/73 [==============================] - 3s 45ms/step - loss: 7.1909e-06 - accuracy: 1.0000
# 16/16 [==============================] - 1s 20ms/step - loss: 1.0660 - accuracy: 0.8921
# Do chinh xac cua ham 0.8921161890029907
# Ham mat mat 1.0659570693969727

# %%
model.save('drive/MyDrive/modelFlower.h5')

# %%
import matplotlib.pyplot as plt
accuracy = train.history['accuracy']
loss = train.history['loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'r-', label = 'Training accuracy')
plt.plot(epochs, loss, 'b', label = 'Training loss')
plt.legend(['Train accuracy', 'Train loss'])
plt.show()

# %%
#Test
import numpy as np
filePath = '/content/drive/MyDrive/Iris.jpg'
testImage = load_img(filePath, color_mode = 'rgb', target_size=(128,128))
arrayImage = img_to_array(testImage).reshape(1,128,128,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", class_Flower[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 328ms/step
# Predicted:  Iris

# %%
#Test
import numpy as np
filePath = '/content/drive/MyDrive/Rose.jpg'
testImage = load_img(filePath, color_mode = 'rgb', target_size=(128,128))
arrayImage = img_to_array(testImage).reshape(1,128,128,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", class_Flower[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Predicted:  Rose

# %%
#Test
import numpy as np
filePath = '/content/drive/MyDrive/Water_Lily.jpg'
testImage = load_img(filePath, color_mode = 'rgb', target_size=(128,128))
arrayImage = img_to_array(testImage).reshape(1,128,128,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", class_Flower[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Predicted:  Water_Lily

# %%
#Test
import numpy as np
filePath = '/content/drive/MyDrive/Daisy.jpg'
testImage = load_img(filePath, color_mode = 'rgb', target_size=(128,128))
arrayImage = img_to_array(testImage).reshape(1,128,128,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", class_Flower[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# Predicted:  Daisy

# %%
#Test
import numpy as np
filePath = '/content/drive/MyDrive/Tulip.jpg'
testImage = load_img(filePath, color_mode = 'rgb', target_size=(128,128))
arrayImage = img_to_array(testImage).reshape(1,128,128,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", class_Flower[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 120ms/step
# Predicted:  Tulip
